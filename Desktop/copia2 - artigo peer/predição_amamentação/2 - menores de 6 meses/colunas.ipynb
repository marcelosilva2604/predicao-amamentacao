# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('/Users/marcelosilva/Desktop/copia2 - artigo peer/predição_amamentação/2 - menores de 6 meses/criancas_menores_6meses.csv')

# Display the number of columns
print(f"Number of columns: {df.shape[1]}")

# Display column names
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Number of columns: 741
#
# Column names:
# ...
